# %%
from ucimlrepo import fetch_ucirepo
wine_quality = fetch_ucirepo(name='Wine Quality')
diabetes = fetch_ucirepo(name='Diabetes 130-US Hospitals for Years 1999-2008')
# Out:
# /Users/alistairkeiller/Documents/cs178Final/.venv/lib/python3.13/site-packages/ucimlrepo/fetch.py:97: DtypeWarning: Columns (0: payer_code) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_url)

# %%
from datasets import load_dataset
fashion_mnist = load_dataset("fashion_mnist")
cifar10 = load_dataset("cifar10")
imdb = load_dataset("imdb")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
