# %%
from autogluon.tabular import TabularPredictor
from utils import load_data

# %%
wine_quality_data = load_data()

# %%
predictor = TabularPredictor(label='quality').fit(
    wine_quality_data, presets="best_quality_v150", hyperparameters={'RF': {}, 'NN_TORCH': {}, 'KNN': {}, 'LR': {},}
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20260311_072542"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.5.0
# Python Version:     3.13.11
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 25.2.0: Tue Nov 18 21:07:05 PST 2025; root:xnu-12377.61.12~1/RELEASE_ARM64_T6020
# CPU Count:          10
# Pytorch Version:    2.9.0
# CUDA Version:       CUDA is not available
# GPU Count:          WARNING: Exception was raised when calculating GPU count (AssertionError)
# Memory Avail:       4.88 GB / 16.00 GB (30.5%)
# Disk Space Avail:   92.26 GB / 460.43 GB (20.0%)
# ===================================================
# Presets specified: ['best_quality_v150']
# Stack configuration (auto_stack=True): num_stack_levels=0, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "/Users/alistairkeiller/Documents/cs178Final/notebooks/AutogluonModels/ag-20260311_072542"
# Train Data Rows:    6497
# Train Data Columns: 12
# Label Column:       quality
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == int, but few unique label-values observed).
# 	7 unique label values:  [np.int64(5), np.int64(6), np.int64(7), np.int64(4), np.int64(8), np.int64(3), np.int64(9)]
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       multiclass
# Preprocessing data ...
# Warning: Some classes in the training set have fewer than 10 examples. AutoGluon will only keep 6 out of 7 classes for training and will not try to predict the rare classes. To keep more classes, increase the number of datapoints from these rare classes in the training data or reduce label_count_threshold.
# Fraction of data from classes with at least 10 examples that will be kept for training models: 0.999230414037248
# Train Data Class Count: 6
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    4995.45 MB
# 	Train Data (Original)  Memory Usage: 0.87 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 11 | ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', ...]
# 		('object', []) :  1 | ['color']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 11 | ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', ...]
# 		('int', ['bool']) :  1 | ['color']
# 	0.1s = Fit runtime
# 	12 features in original data used to generate 12 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.55 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.12s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'RF': [{}],
# 	'NN_TORCH': [{}],
# 	'KNN': [{}],
# 	'LR': [{}],
# }
# User-specified callbacks (1): ['EarlyStoppingCountCallback']
# EarlyStoppingCountCallback: Initializing patience to 29. Reason: num_rows_train=6492, patience_curve=[[100, 4], [500, 8], [2500, 15], [10000, 40], [100000, 100], None]
# Fitting 4 L1 models, fit_strategy="sequential" ...
# Fitting model: KNeighbors_BAG_L1 ... Training model for up to 3599.88s of the 3599.88s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0
# 	0.4965	 = Validation score   (accuracy)
# 	0.0s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForest_BAG_L1 ... Training model for up to 3599.83s of the 3599.83s of remaining time.
# 	Fitting 1 model on all data (use_child_oof=True) | Fitting with cpus=10, gpus=0, mem=0.2/4.9 GB
# 	0.7173	 = Validation score   (accuracy)
# 	0.63s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LinearModel_BAG_L1 ... Training model for up to 3599.00s of the 3599.00s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.07%)
# /Users/alistairkeiller/Documents/cs178Final/.venv/lib/python3.13/site-packages/ray/_private/worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# 	0.5476	 = Validation score   (accuracy)
# 	0.07s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 3591.49s of the 3591.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	0.6526	 = Validation score   (accuracy)
# 	62.87s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 3527.29s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.0/4.1 GB
# 	Ensemble Weights: {'RandomForest_BAG_L1': 0.733, 'LinearModel_BAG_L1': 0.2, 'KNeighbors_BAG_L1': 0.067}
# 	0.7207	 = Validation score   (accuracy)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 72.77s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 16537.1 rows/s (812 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/alistairkeiller/Documents/cs178Final/notebooks/AutogluonModels/ag-20260311_072542")

# %%
predictor.leaderboard(wine_quality_data, silent=True)
# Out:
#                    model  score_test  score_val eval_metric  pred_time_test  \
# 0    RandomForest_BAG_L1    0.999230   0.717344    accuracy        0.133478
# 1    WeightedEnsemble_L2    0.999230   0.720733    accuracy        0.226579
# 2  NeuralNetTorch_BAG_L1    0.977528   0.652649    accuracy        0.147547
# 3      KNeighbors_BAG_L1    0.657842   0.496457    accuracy        0.020790
# 4     LinearModel_BAG_L1    0.551639   0.547597    accuracy        0.070999
#
#    pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0       0.147035   0.626244                 0.133478                0.147035
# 1       0.201507   0.743815                 0.001312                0.000536
# 2       0.081584  62.866485                 0.147547                0.081584
# 3       0.026622   0.004091                 0.020790                0.026622
# 4       0.027314   0.070284                 0.070999                0.027314
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0           0.626244            1       True          2
# 1           0.043196            2       True          5
# 2          62.866485            1       True          4
# 3           0.004091            1       True          1
# 4           0.070284            1       True          3

# %%
predictor.info()
# Out:
# {'path': '/Users/alistairkeiller/Documents/cs178Final/notebooks/AutogluonModels/ag-20260311_072542',
#  'label': 'quality',
#  'random_state': 0,
#  'version': '1.5.0',
#  'features': ['fixed acidity',
#   'volatile acidity',
#   'citric acid',
#   'residual sugar',
#   'chlorides',
#   'free sulfur dioxide',
#   'total sulfur dioxide',
#   'density',
#   'pH',
#   'sulphates',
#   'alcohol',
#   'color'],
#  'feature_metadata_in': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x122332490>,
#  'time_fit_preprocessing': 0.11646294593811035,
#  'time_fit_training': 72.65639901161194,
#  'time_fit_total': 72.77286195755005,
#  'time_limit': 3600,
#  'time_train_start': 1773213949.517022,
#  'num_rows_train': 6492,
#  'num_cols_train': 12,
#  'num_rows_val': None,
#  'num_rows_test': None,
#  'num_classes': 6,
#  'problem_type': 'multiclass',
#  'eval_metric': 'accuracy',
#  'best_model': 'WeightedEnsemble_L2',
#  'best_model_score_val': 0.7207332101047443,
#  'best_model_stack_level': 2,
#  'num_models_trained': 5,
#  'num_bag_folds': 8,
#  'max_stack_level': 2,
#  'max_core_stack_level': 1,
#  'model_info': {'KNeighbors_BAG_L1': {'name': 'KNeighbors_BAG_L1',
#    'model_type': 'StackerEnsembleModel',
#    'problem_type': 'multiclass',
#    'eval_metric': 'accuracy',
#    'stopping_metric': 'accuracy',
#    'fit_time': 0.004091024398803711,
#    'num_classes': 6,
#    'quantile_levels': None,
#    'predict_time': 0.02662181854248047,
#    'val_score': 0.49645717806531114,
#    'hyperparameters': {'use_orig_features': True,
#     'valid_stacker': True,
#     'max_base_models': 0,
#     'max_base_models_per_type': 'auto',
#     'save_bag_folds': True,
#     'stratify': 'auto',
#     'bin': 'auto',
#     'n_bins': None,
#     'vary_seed_across_folds': False,
#     'use_child_oof': True,
#     'model_random_seed': 0},
#    'hyperparameters_user': {'use_child_oof': True},
#    'hyperparameters_fit': {},
#    'hyperparameters_nondefault': ['use_child_oof'],
#    'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#     'max_time_limit_ratio': 1.0,
#     'max_time_limit': None,
#     'min_time_limit': 0,
#     'valid_raw_types': None,
#     'valid_special_types': None,
#     'ignored_type_group_special': None,
#     'ignored_type_group_raw': None,
#     'get_features_kwargs': None,
#     'get_features_kwargs_extra': None,
#     'predict_1_batch_size': None,
#     'temperature_scalar': None,
#     'drop_unique': False},
#    'num_features': 11,
#    'features': ['fixed acidity',
#     'chlorides',
#     'sulphates',
#     'density',
#     'pH',
#     'free sulfur dioxide',
#     'residual sugar',
#     'volatile acidity',
#     'alcohol',
#     'citric acid',
#     'total sulfur dioxide'],
#    'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288bb2f0>,
#    'memory_size': 3688,
#    'compile_time': None,
#    'is_initialized': True,
#    'is_fit': True,
#    'is_valid': True,
#    'can_infer': True,
#    'has_learning_curves': False,
#    'num_samples': 6492,
#    'val_in_fit': False,
#    'unlabeled_in_fit': False,
#    'num_cpus': 10,
#    'num_gpus': 0,
#    'bagged_info': {'child_model_type': 'KNNModel',
#     'num_child_models': 1,
#     'child_model_names': ['S1F1'],
#     '_n_repeats': 1,
#     '_k_per_n_repeat': [1],
#     '_random_state': 1,
#     'low_memory': True,
#     'bagged_mode': False,
#     'max_memory_size': 1021562,
#     'min_memory_size': 1021562,
#     'child_hyperparameters': {'weights': 'uniform'},
#     'child_hyperparameters_user': {},
#     'child_hyperparameters_fit': {},
#     'child_ag_args_fit': {'max_memory_usage_ratio': 1.0,
#      'max_time_limit_ratio': 1.0,
#      'max_time_limit': None,
#      'min_time_limit': 0,
#      'valid_raw_types': ['int', 'float'],
#      'valid_special_types': None,
#      'ignored_type_group_special': ['bool'],
#      'ignored_type_group_raw': None,
#      'get_features_kwargs': None,
#      'get_features_kwargs_extra': None,
#      'predict_1_batch_size': None,
#      'temperature_scalar': None}},
#    'stacker_info': {'num_base_models': 0, 'base_model_names': []},
#    'children_info': {'S1F1': {'name': 'S1F1',
#      'model_type': 'KNNModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 0.004091024398803711,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': 0.02662181854248047,
#      'val_score': 0.49645717806531114,
#      'hyperparameters': {'weights': 'uniform'},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['int', 'float'],
#       'valid_special_types': None,
#       'ignored_type_group_special': ['bool'],
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 11,
#      'features': ['fixed acidity',
#       'volatile acidity',
#       'citric acid',
#       'residual sugar',
#       'chlorides',
#       'free sulfur dioxide',
#       'total sulfur dioxide',
#       'density',
#       'pH',
#       'sulphates',
#       'alcohol'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288baff0>,
#      'memory_size': 1017874,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 6492,
#      'val_in_fit': False,
#      'unlabeled_in_fit': False,
#      'num_cpus': 10,
#      'num_gpus': 0}}},
#   'RandomForest_BAG_L1': {'name': 'RandomForest_BAG_L1',
#    'model_type': 'StackerEnsembleModel',
#    'problem_type': 'multiclass',
#    'eval_metric': 'accuracy',
#    'stopping_metric': 'accuracy',
#    'fit_time': 0.626244068145752,
#    'num_classes': 6,
#    'quantile_levels': None,
#    'predict_time': 0.1470348834991455,
#    'val_score': 0.7173444239063462,
#    'hyperparameters': {'use_orig_features': True,
#     'valid_stacker': True,
#     'max_base_models': 0,
#     'max_base_models_per_type': 'auto',
#     'save_bag_folds': True,
#     'stratify': 'auto',
#     'bin': 'auto',
#     'n_bins': None,
#     'vary_seed_across_folds': False,
#     'use_child_oof': True,
#     'model_random_seed': 0},
#    'hyperparameters_user': {'use_child_oof': True},
#    'hyperparameters_fit': {},
#    'hyperparameters_nondefault': ['use_child_oof'],
#    'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#     'max_time_limit_ratio': 1.0,
#     'max_time_limit': None,
#     'min_time_limit': 0,
#     'valid_raw_types': None,
#     'valid_special_types': None,
#     'ignored_type_group_special': None,
#     'ignored_type_group_raw': None,
#     'get_features_kwargs': None,
#     'get_features_kwargs_extra': None,
#     'predict_1_batch_size': None,
#     'temperature_scalar': None,
#     'drop_unique': False},
#    'num_features': 12,
#    'features': ['fixed acidity',
#     'chlorides',
#     'sulphates',
#     'density',
#     'pH',
#     'free sulfur dioxide',
#     'residual sugar',
#     'color',
#     'volatile acidity',
#     'alcohol',
#     'citric acid',
#     'total sulfur dioxide'],
#    'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1284b5e50>,
#    'memory_size': 3698,
#    'compile_time': None,
#    'is_initialized': True,
#    'is_fit': True,
#    'is_valid': True,
#    'can_infer': True,
#    'has_learning_curves': False,
#    'num_samples': 6492,
#    'val_in_fit': False,
#    'unlabeled_in_fit': False,
#    'num_cpus': 10,
#    'num_gpus': 0,
#    'bagged_info': {'child_model_type': 'RFModel',
#     'num_child_models': 1,
#     'child_model_names': ['S1F1'],
#     '_n_repeats': 1,
#     '_k_per_n_repeat': [1],
#     '_random_state': 1,
#     'low_memory': True,
#     'bagged_mode': False,
#     'max_memory_size': 99492279,
#     'min_memory_size': 99492279,
#     'child_hyperparameters': {'n_estimators': 300,
#      'max_leaf_nodes': 15000,
#      'n_jobs': -1,
#      'bootstrap': True,
#      'random_state': 0},
#     'child_hyperparameters_user': {},
#     'child_hyperparameters_fit': {'n_estimators': 300},
#     'child_ag_args_fit': {'max_memory_usage_ratio': 1.0,
#      'max_time_limit_ratio': 1.0,
#      'max_time_limit': None,
#      'min_time_limit': 0,
#      'valid_raw_types': ['bool', 'int', 'float', 'category'],
#      'valid_special_types': None,
#      'ignored_type_group_special': None,
#      'ignored_type_group_raw': None,
#      'get_features_kwargs': None,
#      'get_features_kwargs_extra': None,
#      'predict_1_batch_size': None,
#      'temperature_scalar': None}},
#    'stacker_info': {'num_base_models': 0, 'base_model_names': []},
#    'children_info': {'S1F1': {'name': 'S1F1',
#      'model_type': 'RFModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 0.626244068145752,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': 0.1470348834991455,
#      'val_score': 0.7173444239063462,
#      'hyperparameters': {'n_estimators': 300,
#       'max_leaf_nodes': 15000,
#       'n_jobs': -1,
#       'bootstrap': True,
#       'random_state': 0},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {'n_estimators': 300},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': None,
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 12,
#      'features': ['fixed acidity',
#       'volatile acidity',
#       'citric acid',
#       'residual sugar',
#       'chlorides',
#       'free sulfur dioxide',
#       'total sulfur dioxide',
#       'density',
#       'pH',
#       'sulphates',
#       'alcohol',
#       'color'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x128a019d0>,
#      'memory_size': 99488581,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 6492,
#      'val_in_fit': False,
#      'unlabeled_in_fit': False,
#      'num_cpus': 10,
#      'num_gpus': 0}}},
#   'LinearModel_BAG_L1': {'name': 'LinearModel_BAG_L1',
#    'model_type': 'StackerEnsembleModel',
#    'problem_type': 'multiclass',
#    'eval_metric': 'accuracy',
#    'stopping_metric': 'accuracy',
#    'fit_time': 0.07028388977050781,
#    'num_classes': 6,
#    'quantile_levels': None,
#    'predict_time': 0.027314186096191406,
#    'val_score': 0.5475970425138632,
#    'hyperparameters': {'use_orig_features': True,
#     'valid_stacker': True,
#     'max_base_models': 0,
#     'max_base_models_per_type': 'auto',
#     'save_bag_folds': True,
#     'stratify': 'auto',
#     'bin': 'auto',
#     'n_bins': None,
#     'vary_seed_across_folds': False,
#     'model_random_seed': 0},
#    'hyperparameters_user': {},
#    'hyperparameters_fit': {},
#    'hyperparameters_nondefault': [],
#    'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#     'max_time_limit_ratio': 1.0,
#     'max_time_limit': None,
#     'min_time_limit': 0,
#     'valid_raw_types': None,
#     'valid_special_types': None,
#     'ignored_type_group_special': None,
#     'ignored_type_group_raw': None,
#     'get_features_kwargs': None,
#     'get_features_kwargs_extra': None,
#     'predict_1_batch_size': None,
#     'temperature_scalar': None,
#     'drop_unique': False},
#    'num_features': 12,
#    'features': ['fixed acidity',
#     'chlorides',
#     'sulphates',
#     'density',
#     'pH',
#     'free sulfur dioxide',
#     'residual sugar',
#     'color',
#     'volatile acidity',
#     'alcohol',
#     'citric acid',
#     'total sulfur dioxide'],
#    'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288b9310>,
#    'memory_size': 4045,
#    'compile_time': None,
#    'is_initialized': True,
#    'is_fit': True,
#    'is_valid': True,
#    'can_infer': True,
#    'has_learning_curves': False,
#    'num_samples': 6492,
#    'val_in_fit': False,
#    'unlabeled_in_fit': False,
#    'num_cpus': 10,
#    'num_gpus': 0,
#    'bagged_info': {'child_model_type': 'LinearModel',
#     'num_child_models': 8,
#     'child_model_names': ['S1F1',
#      'S1F2',
#      'S1F3',
#      'S1F4',
#      'S1F5',
#      'S1F6',
#      'S1F7',
#      'S1F8'],
#     '_n_repeats': 1,
#     '_k_per_n_repeat': [8],
#     '_random_state': 1,
#     'low_memory': True,
#     'bagged_mode': True,
#     'max_memory_size': 502669,
#     'min_memory_size': 67370,
#     'child_hyperparameters': {'fit_intercept': True,
#      'solver': 'lbfgs',
#      'C': 1,
#      'vectorizer_dict_size': 75000,
#      'proc.ngram_range': (1, 5),
#      'proc.skew_threshold': 0.99,
#      'proc.impute_strategy': 'median',
#      'penalty': 'L2',
#      'handle_text': 'ignore',
#      'random_state': 0},
#     'child_hyperparameters_user': {},
#     'child_hyperparameters_fit': {'max_iter': 10000},
#     'child_ag_args_fit': {'max_memory_usage_ratio': 1.0,
#      'max_time_limit_ratio': 1.0,
#      'max_time_limit': None,
#      'min_time_limit': 0,
#      'valid_raw_types': ['bool', 'int', 'float', 'category'],
#      'valid_special_types': None,
#      'ignored_type_group_special': ['text_as_category'],
#      'ignored_type_group_raw': None,
#      'get_features_kwargs': None,
#      'get_features_kwargs_extra': None,
#      'predict_1_batch_size': None,
#      'temperature_scalar': None}},
#    'stacker_info': {'num_base_models': 0, 'base_model_names': []},
#    'children_info': {'S1F1': {'name': 'S1F1',
#      'model_type': 'LinearModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 0.06881308555603027,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': 0.003802061080932617,
#      'val_score': 0.5492610837438424,
#      'hyperparameters': {'fit_intercept': True,
#       'solver': 'lbfgs',
#       'C': 1,
#       'vectorizer_dict_size': 75000,
#       'proc.ngram_range': (1, 5),
#       'proc.skew_threshold': 0.99,
#       'proc.impute_strategy': 'median',
#       'penalty': 'L2',
#       'handle_text': 'ignore',
#       'random_state': 0},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {'max_iter': 10000},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': ['text_as_category'],
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 12,
#      'features': ['fixed acidity',
#       'volatile acidity',
#       'citric acid',
#       'residual sugar',
#       'chlorides',
#       'free sulfur dioxide',
#       'total sulfur dioxide',
#       'density',
#       'pH',
#       'sulphates',
#       'alcohol',
#       'color'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288ba330>,
#      'memory_size': 63325,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 5680,
#      'val_in_fit': True,
#      'unlabeled_in_fit': False,
#      'num_cpus': 1,
#      'num_gpus': 0},
#     'S1F2': {'name': 'S1F2',
#      'model_type': 'LinearModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 0.061308860778808594,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': 0.003394603729248047,
#      'val_score': 0.5492610837438424,
#      'hyperparameters': {'fit_intercept': True,
#       'solver': 'lbfgs',
#       'C': 1,
#       'vectorizer_dict_size': 75000,
#       'proc.ngram_range': (1, 5),
#       'proc.skew_threshold': 0.99,
#       'proc.impute_strategy': 'median',
#       'penalty': 'L2',
#       'handle_text': 'ignore',
#       'random_state': 0},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {'max_iter': 10000},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': ['text_as_category'],
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 12,
#      'features': ['fixed acidity',
#       'volatile acidity',
#       'citric acid',
#       'residual sugar',
#       'chlorides',
#       'free sulfur dioxide',
#       'total sulfur dioxide',
#       'density',
#       'pH',
#       'sulphates',
#       'alcohol',
#       'color'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288baab0>,
#      'memory_size': 63325,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 5680,
#      'val_in_fit': True,
#      'unlabeled_in_fit': False,
#      'num_cpus': 1,
#      'num_gpus': 0},
#     'S1F3': {'name': 'S1F3',
#      'model_type': 'LinearModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 0.06866788864135742,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': 0.003381013870239258,
#      'val_score': 0.5320197044334976,
#      'hyperparameters': {'fit_intercept': True,
#       'solver': 'lbfgs',
#       'C': 1,
#       'vectorizer_dict_size': 75000,
#       'proc.ngram_range': (1, 5),
#       'proc.skew_threshold': 0.99,
#       'proc.impute_strategy': 'median',
#       'penalty': 'L2',
#       'handle_text': 'ignore',
#       'random_state': 0},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {'max_iter': 10000},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': ['text_as_category'],
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 12,
#      'features': ['fixed acidity',
#       'volatile acidity',
#       'citric acid',
#       'residual sugar',
#       'chlorides',
#       'free sulfur dioxide',
#       'total sulfur dioxide',
#       'density',
#       'pH',
#       'sulphates',
#       'alcohol',
#       'color'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288bbbf0>,
#      'memory_size': 55349,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 5680,
#      'val_in_fit': True,
#      'unlabeled_in_fit': False,
#      'num_cpus': 1,
#      'num_gpus': 0},
#     'S1F4': {'name': 'S1F4',
#      'model_type': 'LinearModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 0.05321812629699707,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': 0.003354787826538086,
#      'val_score': 0.5652709359605911,
#      'hyperparameters': {'fit_intercept': True,
#       'solver': 'lbfgs',
#       'C': 1,
#       'vectorizer_dict_size': 75000,
#       'proc.ngram_range': (1, 5),
#       'proc.skew_threshold': 0.99,
#       'proc.impute_strategy': 'median',
#       'penalty': 'L2',
#       'handle_text': 'ignore',
#       'random_state': 0},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {'max_iter': 10000},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': ['text_as_category'],
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 12,
#      'features': ['fixed acidity',
#       'volatile acidity',
#       'citric acid',
#       'residual sugar',
#       'chlorides',
#       'free sulfur dioxide',
#       'total sulfur dioxide',
#       'density',
#       'pH',
#       'sulphates',
#       'alcohol',
#       'color'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288bae70>,
#      'memory_size': 63325,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 5680,
#      'val_in_fit': True,
#      'unlabeled_in_fit': False,
#      'num_cpus': 1,
#      'num_gpus': 0},
#     'S1F5': {'name': 'S1F5',
#      'model_type': 'LinearModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 0.06908178329467773,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': 0.003223896026611328,
#      'val_score': 0.55980271270037,
#      'hyperparameters': {'fit_intercept': True,
#       'solver': 'lbfgs',
#       'C': 1,
#       'vectorizer_dict_size': 75000,
#       'proc.ngram_range': (1, 5),
#       'proc.skew_threshold': 0.99,
#       'proc.impute_strategy': 'median',
#       'penalty': 'L2',
#       'handle_text': 'ignore',
#       'random_state': 0},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {'max_iter': 10000},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': ['text_as_category'],
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 12,
#      'features': ['fixed acidity',
#       'volatile acidity',
#       'citric acid',
#       'residual sugar',
#       'chlorides',
#       'free sulfur dioxide',
#       'total sulfur dioxide',
#       'density',
#       'pH',
#       'sulphates',
#       'alcohol',
#       'color'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288b9730>,
#      'memory_size': 63325,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 5681,
#      'val_in_fit': True,
#      'unlabeled_in_fit': False,
#      'num_cpus': 1,
#      'num_gpus': 0},
#     'S1F6': {'name': 'S1F6',
#      'model_type': 'LinearModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 0.060797929763793945,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': 0.0034639835357666016,
#      'val_score': 0.5487053020961775,
#      'hyperparameters': {'fit_intercept': True,
#       'solver': 'lbfgs',
#       'C': 1,
#       'vectorizer_dict_size': 75000,
#       'proc.ngram_range': (1, 5),
#       'proc.skew_threshold': 0.99,
#       'proc.impute_strategy': 'median',
#       'penalty': 'L2',
#       'handle_text': 'ignore',
#       'random_state': 0},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {'max_iter': 10000},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': ['text_as_category'],
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 12,
#      'features': ['fixed acidity',
#       'volatile acidity',
#       'citric acid',
#       'residual sugar',
#       'chlorides',
#       'free sulfur dioxide',
#       'total sulfur dioxide',
#       'density',
#       'pH',
#       'sulphates',
#       'alcohol',
#       'color'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288bb530>,
#      'memory_size': 63325,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 5681,
#      'val_in_fit': True,
#      'unlabeled_in_fit': False,
#      'num_cpus': 1,
#      'num_gpus': 0},
#     'S1F7': {'name': 'S1F7',
#      'model_type': 'LinearModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 0.05615091323852539,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': 0.003331899642944336,
#      'val_score': 0.5215782983970407,
#      'hyperparameters': {'fit_intercept': True,
#       'solver': 'lbfgs',
#       'C': 1,
#       'vectorizer_dict_size': 75000,
#       'proc.ngram_range': (1, 5),
#       'proc.skew_threshold': 0.99,
#       'proc.impute_strategy': 'median',
#       'penalty': 'L2',
#       'handle_text': 'ignore',
#       'random_state': 0},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {'max_iter': 10000},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': ['text_as_category'],
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 12,
#      'features': ['fixed acidity',
#       'volatile acidity',
#       'citric acid',
#       'residual sugar',
#       'chlorides',
#       'free sulfur dioxide',
#       'total sulfur dioxide',
#       'density',
#       'pH',
#       'sulphates',
#       'alcohol',
#       'color'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288ba0f0>,
#      'memory_size': 63325,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 5681,
#      'val_in_fit': True,
#      'unlabeled_in_fit': False,
#      'num_cpus': 1,
#      'num_gpus': 0},
#     'S1F8': {'name': 'S1F8',
#      'model_type': 'LinearModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 0.06843376159667969,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': 0.003361940383911133,
#      'val_score': 0.5548705302096177,
#      'hyperparameters': {'fit_intercept': True,
#       'solver': 'lbfgs',
#       'C': 1,
#       'vectorizer_dict_size': 75000,
#       'proc.ngram_range': (1, 5),
#       'proc.skew_threshold': 0.99,
#       'proc.impute_strategy': 'median',
#       'penalty': 'L2',
#       'handle_text': 'ignore',
#       'random_state': 0},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {'max_iter': 10000},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': ['text_as_category'],
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 12,
#      'features': ['fixed acidity',
#       'volatile acidity',
#       'citric acid',
#       'residual sugar',
#       'chlorides',
#       'free sulfur dioxide',
#       'total sulfur dioxide',
#       'density',
#       'pH',
#       'sulphates',
#       'alcohol',
#       'color'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288b89b0>,
#      'memory_size': 63325,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 5681,
#      'val_in_fit': True,
#      'unlabeled_in_fit': False,
#      'num_cpus': 1,
#      'num_gpus': 0}}},
#   'NeuralNetTorch_BAG_L1': {'name': 'NeuralNetTorch_BAG_L1',
#    'model_type': 'StackerEnsembleModel',
#    'problem_type': 'multiclass',
#    'eval_metric': 'accuracy',
#    'stopping_metric': 'accuracy',
#    'fit_time': 62.86648511886597,
#    'num_classes': 6,
#    'quantile_levels': None,
#    'predict_time': 0.08158397674560547,
#    'val_score': 0.6526494146642021,
#    'hyperparameters': {'use_orig_features': True,
#     'valid_stacker': True,
#     'max_base_models': 0,
#     'max_base_models_per_type': 'auto',
#     'save_bag_folds': True,
#     'stratify': 'auto',
#     'bin': 'auto',
#     'n_bins': None,
#     'vary_seed_across_folds': False,
#     'model_random_seed': 0},
#    'hyperparameters_user': {},
#    'hyperparameters_fit': {},
#    'hyperparameters_nondefault': [],
#    'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#     'max_time_limit_ratio': 1.0,
#     'max_time_limit': None,
#     'min_time_limit': 0,
#     'valid_raw_types': None,
#     'valid_special_types': None,
#     'ignored_type_group_special': None,
#     'ignored_type_group_raw': None,
#     'get_features_kwargs': None,
#     'get_features_kwargs_extra': None,
#     'predict_1_batch_size': None,
#     'temperature_scalar': None,
#     'drop_unique': False},
#    'num_features': 12,
#    'features': ['fixed acidity',
#     'chlorides',
#     'sulphates',
#     'density',
#     'pH',
#     'free sulfur dioxide',
#     'residual sugar',
#     'color',
#     'volatile acidity',
#     'alcohol',
#     'citric acid',
#     'total sulfur dioxide'],
#    'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288b9e50>,
#    'memory_size': 4102,
#    'compile_time': None,
#    'is_initialized': True,
#    'is_fit': True,
#    'is_valid': True,
#    'can_infer': True,
#    'has_learning_curves': False,
#    'num_samples': 6492,
#    'val_in_fit': False,
#    'unlabeled_in_fit': False,
#    'num_cpus': 10,
#    'num_gpus': 0,
#    'bagged_info': {'child_model_type': 'TabularNeuralNetTorchModel',
#     'num_child_models': 8,
#     'child_model_names': ['S1F1',
#      'S1F2',
#      'S1F3',
#      'S1F4',
#      'S1F5',
#      'S1F6',
#      'S1F7',
#      'S1F8'],
#     '_n_repeats': 1,
#     '_k_per_n_repeat': [8],
#     '_random_state': 1,
#     'low_memory': True,
#     'bagged_mode': True,
#     'max_memory_size': 2213091,
#     'min_memory_size': 281224,
#     'child_hyperparameters': {'num_epochs': 1000,
#      'epochs_wo_improve': None,
#      'activation': 'relu',
#      'embedding_size_factor': 1.0,
#      'embed_exponent': 0.56,
#      'max_embedding_dim': 100,
#      'y_range': None,
#      'y_range_extend': 0.05,
#      'dropout_prob': 0.1,
#      'optimizer': 'adam',
#      'learning_rate': 0.0003,
#      'weight_decay': 1e-06,
#      'proc.embed_min_categories': 4,
#      'proc.impute_strategy': 'median',
#      'proc.max_category_levels': 100,
#      'proc.skew_threshold': 0.99,
#      'use_ngram_features': False,
#      'num_layers': 4,
#      'hidden_size': 128,
#      'max_batch_size': 512,
#      'use_batchnorm': False,
#      'loss_function': 'auto',
#      'seed_value': 0},
#     'child_hyperparameters_user': {},
#     'child_hyperparameters_fit': {'batch_size': 64, 'num_epochs': 420},
#     'child_ag_args_fit': {'max_memory_usage_ratio': 1.0,
#      'max_time_limit_ratio': 1.0,
#      'max_time_limit': None,
#      'min_time_limit': 0,
#      'valid_raw_types': ['bool', 'int', 'float', 'category'],
#      'valid_special_types': None,
#      'ignored_type_group_special': ['text_ngram', 'text_as_category'],
#      'ignored_type_group_raw': None,
#      'get_features_kwargs': None,
#      'get_features_kwargs_extra': None,
#      'predict_1_batch_size': None,
#      'temperature_scalar': None}},
#    'stacker_info': {'num_base_models': 0, 'base_model_names': []},
#    'children_info': {'S1F1': {'name': 'S1F1',
#      'model_type': 'TabularNeuralNetTorchModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 7.623924970626831,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': 0.008026123046875,
#      'val_score': 0.5935960591133005,
#      'hyperparameters': {'num_epochs': 1000,
#       'epochs_wo_improve': None,
#       'activation': 'relu',
#       'embedding_size_factor': 1.0,
#       'embed_exponent': 0.56,
#       'max_embedding_dim': 100,
#       'y_range': None,
#       'y_range_extend': 0.05,
#       'dropout_prob': 0.1,
#       'optimizer': 'adam',
#       'learning_rate': 0.0003,
#       'weight_decay': 1e-06,
#       'proc.embed_min_categories': 4,
#       'proc.impute_strategy': 'median',
#       'proc.max_category_levels': 100,
#       'proc.skew_threshold': 0.99,
#       'use_ngram_features': False,
#       'num_layers': 4,
#       'hidden_size': 128,
#       'max_batch_size': 512,
#       'use_batchnorm': False,
#       'loss_function': 'auto',
#       'seed_value': 0},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {'batch_size': 64, 'num_epochs': 33},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': ['text_ngram', 'text_as_category'],
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 12,
#      'features': ['fixed acidity',
#       'volatile acidity',
#       'citric acid',
#       'residual sugar',
#       'chlorides',
#       'free sulfur dioxide',
#       'total sulfur dioxide',
#       'density',
#       'pH',
#       'sulphates',
#       'alcohol',
#       'color'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288bb290>,
#      'memory_size': 277121,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 5680,
#      'val_in_fit': True,
#      'unlabeled_in_fit': False,
#      'num_cpus': 1,
#      'num_gpus': 0},
#     'S1F2': {'name': 'S1F2',
#      'model_type': 'TabularNeuralNetTorchModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 62.226678133010864,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': 0.00830984115600586,
#      'val_score': 0.7056650246305419,
#      'hyperparameters': {'num_epochs': 1000,
#       'epochs_wo_improve': None,
#       'activation': 'relu',
#       'embedding_size_factor': 1.0,
#       'embed_exponent': 0.56,
#       'max_embedding_dim': 100,
#       'y_range': None,
#       'y_range_extend': 0.05,
#       'dropout_prob': 0.1,
#       'optimizer': 'adam',
#       'learning_rate': 0.0003,
#       'weight_decay': 1e-06,
#       'proc.embed_min_categories': 4,
#       'proc.impute_strategy': 'median',
#       'proc.max_category_levels': 100,
#       'proc.skew_threshold': 0.99,
#       'use_ngram_features': False,
#       'num_layers': 4,
#       'hidden_size': 128,
#       'max_batch_size': 512,
#       'use_batchnorm': False,
#       'loss_function': 'auto',
#       'seed_value': 0},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {'batch_size': 64, 'num_epochs': 887},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': ['text_ngram', 'text_as_category'],
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 12,
#      'features': ['fixed acidity',
#       'volatile acidity',
#       'citric acid',
#       'residual sugar',
#       'chlorides',
#       'free sulfur dioxide',
#       'total sulfur dioxide',
#       'density',
#       'pH',
#       'sulphates',
#       'alcohol',
#       'color'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288ba930>,
#      'memory_size': 277122,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 5680,
#      'val_in_fit': True,
#      'unlabeled_in_fit': False,
#      'num_cpus': 1,
#      'num_gpus': 0},
#     'S1F3': {'name': 'S1F3',
#      'model_type': 'TabularNeuralNetTorchModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 37.64401698112488,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': 0.007992029190063477,
#      'val_score': 0.6884236453201971,
#      'hyperparameters': {'num_epochs': 1000,
#       'epochs_wo_improve': None,
#       'activation': 'relu',
#       'embedding_size_factor': 1.0,
#       'embed_exponent': 0.56,
#       'max_embedding_dim': 100,
#       'y_range': None,
#       'y_range_extend': 0.05,
#       'dropout_prob': 0.1,
#       'optimizer': 'adam',
#       'learning_rate': 0.0003,
#       'weight_decay': 1e-06,
#       'proc.embed_min_categories': 4,
#       'proc.impute_strategy': 'median',
#       'proc.max_category_levels': 100,
#       'proc.skew_threshold': 0.99,
#       'use_ngram_features': False,
#       'num_layers': 4,
#       'hidden_size': 128,
#       'max_batch_size': 512,
#       'use_batchnorm': False,
#       'loss_function': 'auto',
#       'seed_value': 0},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {'batch_size': 64, 'num_epochs': 374},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': ['text_ngram', 'text_as_category'],
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 12,
#      'features': ['fixed acidity',
#       'volatile acidity',
#       'citric acid',
#       'residual sugar',
#       'chlorides',
#       'free sulfur dioxide',
#       'total sulfur dioxide',
#       'density',
#       'pH',
#       'sulphates',
#       'alcohol',
#       'color'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288bbb90>,
#      'memory_size': 269137,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 5680,
#      'val_in_fit': True,
#      'unlabeled_in_fit': False,
#      'num_cpus': 1,
#      'num_gpus': 0},
#     'S1F4': {'name': 'S1F4',
#      'model_type': 'TabularNeuralNetTorchModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 33.16711926460266,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': 0.008152008056640625,
#      'val_score': 0.6773399014778325,
#      'hyperparameters': {'num_epochs': 1000,
#       'epochs_wo_improve': None,
#       'activation': 'relu',
#       'embedding_size_factor': 1.0,
#       'embed_exponent': 0.56,
#       'max_embedding_dim': 100,
#       'y_range': None,
#       'y_range_extend': 0.05,
#       'dropout_prob': 0.1,
#       'optimizer': 'adam',
#       'learning_rate': 0.0003,
#       'weight_decay': 1e-06,
#       'proc.embed_min_categories': 4,
#       'proc.impute_strategy': 'median',
#       'proc.max_category_levels': 100,
#       'proc.skew_threshold': 0.99,
#       'use_ngram_features': False,
#       'num_layers': 4,
#       'hidden_size': 128,
#       'max_batch_size': 512,
#       'use_batchnorm': False,
#       'loss_function': 'auto',
#       'seed_value': 0},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {'batch_size': 64, 'num_epochs': 322},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': ['text_ngram', 'text_as_category'],
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 12,
#      'features': ['fixed acidity',
#       'volatile acidity',
#       'citric acid',
#       'residual sugar',
#       'chlorides',
#       'free sulfur dioxide',
#       'total sulfur dioxide',
#       'density',
#       'pH',
#       'sulphates',
#       'alcohol',
#       'color'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288bbc50>,
#      'memory_size': 277122,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 5680,
#      'val_in_fit': True,
#      'unlabeled_in_fit': False,
#      'num_cpus': 1,
#      'num_gpus': 0},
#     'S1F5': {'name': 'S1F5',
#      'model_type': 'TabularNeuralNetTorchModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 33.493480920791626,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': 0.010787248611450195,
#      'val_score': 0.657213316892725,
#      'hyperparameters': {'num_epochs': 1000,
#       'epochs_wo_improve': None,
#       'activation': 'relu',
#       'embedding_size_factor': 1.0,
#       'embed_exponent': 0.56,
#       'max_embedding_dim': 100,
#       'y_range': None,
#       'y_range_extend': 0.05,
#       'dropout_prob': 0.1,
#       'optimizer': 'adam',
#       'learning_rate': 0.0003,
#       'weight_decay': 1e-06,
#       'proc.embed_min_categories': 4,
#       'proc.impute_strategy': 'median',
#       'proc.max_category_levels': 100,
#       'proc.skew_threshold': 0.99,
#       'use_ngram_features': False,
#       'num_layers': 4,
#       'hidden_size': 128,
#       'max_batch_size': 512,
#       'use_batchnorm': False,
#       'loss_function': 'auto',
#       'seed_value': 0},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {'batch_size': 64, 'num_epochs': 307},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': ['text_ngram', 'text_as_category'],
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 12,
#      'features': ['fixed acidity',
#       'volatile acidity',
#       'citric acid',
#       'residual sugar',
#       'chlorides',
#       'free sulfur dioxide',
#       'total sulfur dioxide',
#       'density',
#       'pH',
#       'sulphates',
#       'alcohol',
#       'color'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288bab10>,
#      'memory_size': 277122,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 5681,
#      'val_in_fit': True,
#      'unlabeled_in_fit': False,
#      'num_cpus': 1,
#      'num_gpus': 0},
#     'S1F6': {'name': 'S1F6',
#      'model_type': 'TabularNeuralNetTorchModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 31.225042819976807,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': 0.011527776718139648,
#      'val_score': 0.6498150431565968,
#      'hyperparameters': {'num_epochs': 1000,
#       'epochs_wo_improve': None,
#       'activation': 'relu',
#       'embedding_size_factor': 1.0,
#       'embed_exponent': 0.56,
#       'max_embedding_dim': 100,
#       'y_range': None,
#       'y_range_extend': 0.05,
#       'dropout_prob': 0.1,
#       'optimizer': 'adam',
#       'learning_rate': 0.0003,
#       'weight_decay': 1e-06,
#       'proc.embed_min_categories': 4,
#       'proc.impute_strategy': 'median',
#       'proc.max_category_levels': 100,
#       'proc.skew_threshold': 0.99,
#       'use_ngram_features': False,
#       'num_layers': 4,
#       'hidden_size': 128,
#       'max_batch_size': 512,
#       'use_batchnorm': False,
#       'loss_function': 'auto',
#       'seed_value': 0},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {'batch_size': 64, 'num_epochs': 449},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': ['text_ngram', 'text_as_category'],
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 12,
#      'features': ['fixed acidity',
#       'volatile acidity',
#       'citric acid',
#       'residual sugar',
#       'chlorides',
#       'free sulfur dioxide',
#       'total sulfur dioxide',
#       'density',
#       'pH',
#       'sulphates',
#       'alcohol',
#       'color'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288bb9b0>,
#      'memory_size': 277122,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 5681,
#      'val_in_fit': True,
#      'unlabeled_in_fit': False,
#      'num_cpus': 1,
#      'num_gpus': 0},
#     'S1F7': {'name': 'S1F7',
#      'model_type': 'TabularNeuralNetTorchModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 4.796166896820068,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': 0.009038925170898438,
#      'val_score': 0.5758323057953144,
#      'hyperparameters': {'num_epochs': 1000,
#       'epochs_wo_improve': None,
#       'activation': 'relu',
#       'embedding_size_factor': 1.0,
#       'embed_exponent': 0.56,
#       'max_embedding_dim': 100,
#       'y_range': None,
#       'y_range_extend': 0.05,
#       'dropout_prob': 0.1,
#       'optimizer': 'adam',
#       'learning_rate': 0.0003,
#       'weight_decay': 1e-06,
#       'proc.embed_min_categories': 4,
#       'proc.impute_strategy': 'median',
#       'proc.max_category_levels': 100,
#       'proc.skew_threshold': 0.99,
#       'use_ngram_features': False,
#       'num_layers': 4,
#       'hidden_size': 128,
#       'max_batch_size': 512,
#       'use_batchnorm': False,
#       'loss_function': 'auto',
#       'seed_value': 0},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {'batch_size': 64, 'num_epochs': 27},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': ['text_ngram', 'text_as_category'],
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 12,
#      'features': ['fixed acidity',
#       'volatile acidity',
#       'citric acid',
#       'residual sugar',
#       'chlorides',
#       'free sulfur dioxide',
#       'total sulfur dioxide',
#       'density',
#       'pH',
#       'sulphates',
#       'alcohol',
#       'color'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288b9d30>,
#      'memory_size': 277121,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 5681,
#      'val_in_fit': True,
#      'unlabeled_in_fit': False,
#      'num_cpus': 1,
#      'num_gpus': 0},
#     'S1F8': {'name': 'S1F8',
#      'model_type': 'TabularNeuralNetTorchModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 61.33680009841919,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': 0.017750024795532227,
#      'val_score': 0.6732429099876696,
#      'hyperparameters': {'num_epochs': 1000,
#       'epochs_wo_improve': None,
#       'activation': 'relu',
#       'embedding_size_factor': 1.0,
#       'embed_exponent': 0.56,
#       'max_embedding_dim': 100,
#       'y_range': None,
#       'y_range_extend': 0.05,
#       'dropout_prob': 0.1,
#       'optimizer': 'adam',
#       'learning_rate': 0.0003,
#       'weight_decay': 1e-06,
#       'proc.embed_min_categories': 4,
#       'proc.impute_strategy': 'median',
#       'proc.max_category_levels': 100,
#       'proc.skew_threshold': 0.99,
#       'use_ngram_features': False,
#       'num_layers': 4,
#       'hidden_size': 128,
#       'max_batch_size': 512,
#       'use_batchnorm': False,
#       'loss_function': 'auto',
#       'seed_value': 0},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {'batch_size': 64, 'num_epochs': 958},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': ['bool', 'int', 'float', 'category'],
#       'valid_special_types': None,
#       'ignored_type_group_special': ['text_ngram', 'text_as_category'],
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None},
#      'num_features': 12,
#      'features': ['fixed acidity',
#       'volatile acidity',
#       'citric acid',
#       'residual sugar',
#       'chlorides',
#       'free sulfur dioxide',
#       'total sulfur dioxide',
#       'density',
#       'pH',
#       'sulphates',
#       'alcohol',
#       'color'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288b9c10>,
#      'memory_size': 277122,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 5681,
#      'val_in_fit': True,
#      'unlabeled_in_fit': False,
#      'num_cpus': 1,
#      'num_gpus': 0}}},
#   'WeightedEnsemble_L2': {'name': 'WeightedEnsemble_L2',
#    'model_type': 'WeightedEnsembleModel',
#    'problem_type': 'multiclass',
#    'eval_metric': 'accuracy',
#    'stopping_metric': 'accuracy',
#    'fit_time': 0.04319596290588379,
#    'num_classes': 6,
#    'quantile_levels': None,
#    'predict_time': 0.0005362033843994141,
#    'val_score': 0.7207332101047443,
#    'hyperparameters': {'use_orig_features': False,
#     'valid_stacker': True,
#     'max_base_models': 0,
#     'max_base_models_per_type': 'auto',
#     'save_bag_folds': True,
#     'stratify': 'auto',
#     'bin': 'auto',
#     'n_bins': None,
#     'vary_seed_across_folds': False,
#     'model_random_seed': 0},
#    'hyperparameters_user': {'save_bag_folds': True},
#    'hyperparameters_fit': {},
#    'hyperparameters_nondefault': ['save_bag_folds'],
#    'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#     'max_time_limit_ratio': 1.0,
#     'max_time_limit': None,
#     'min_time_limit': 0,
#     'valid_raw_types': None,
#     'valid_special_types': None,
#     'ignored_type_group_special': None,
#     'ignored_type_group_raw': None,
#     'get_features_kwargs': None,
#     'get_features_kwargs_extra': None,
#     'predict_1_batch_size': None,
#     'temperature_scalar': None,
#     'drop_unique': False},
#    'num_features': 18,
#    'features': ['LinearModel_BAG_L1_1',
#     'KNeighbors_BAG_L1_4',
#     'KNeighbors_BAG_L1_0',
#     'KNeighbors_BAG_L1_3',
#     'RandomForest_BAG_L1_4',
#     'KNeighbors_BAG_L1_2',
#     'RandomForest_BAG_L1_0',
#     'LinearModel_BAG_L1_0',
#     'RandomForest_BAG_L1_3',
#     'KNeighbors_BAG_L1_5',
#     'LinearModel_BAG_L1_4',
#     'KNeighbors_BAG_L1_1',
#     'LinearModel_BAG_L1_3',
#     'RandomForest_BAG_L1_2',
#     'LinearModel_BAG_L1_2',
#     'RandomForest_BAG_L1_5',
#     'LinearModel_BAG_L1_5',
#     'RandomForest_BAG_L1_1'],
#    'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1288b92b0>,
#    'memory_size': 5115,
#    'compile_time': None,
#    'is_initialized': True,
#    'is_fit': True,
#    'is_valid': True,
#    'can_infer': True,
#    'has_learning_curves': False,
#    'num_samples': 6492,
#    'val_in_fit': False,
#    'unlabeled_in_fit': False,
#    'num_cpus': 10,
#    'num_gpus': 0,
#    'bagged_info': {'child_model_type': 'GreedyWeightedEnsembleModel',
#     'num_child_models': 1,
#     'child_model_names': ['S1F1'],
#     '_n_repeats': 1,
#     '_k_per_n_repeat': [1],
#     '_random_state': 2,
#     'low_memory': False,
#     'bagged_mode': False,
#     'max_memory_size': 5115,
#     'min_memory_size': 5115,
#     'child_hyperparameters': {'ensemble_size': 25, 'subsample_size': 1000000},
#     'child_hyperparameters_user': {},
#     'child_hyperparameters_fit': {'ensemble_size': 15},
#     'child_ag_args_fit': {'max_memory_usage_ratio': 1.0,
#      'max_time_limit_ratio': 1.0,
#      'max_time_limit': None,
#      'min_time_limit': 0,
#      'valid_raw_types': None,
#      'valid_special_types': None,
#      'ignored_type_group_special': None,
#      'ignored_type_group_raw': None,
#      'get_features_kwargs': None,
#      'get_features_kwargs_extra': None,
#      'predict_1_batch_size': None,
#      'temperature_scalar': None,
#      'drop_unique': False}},
#    'stacker_info': {'num_base_models': 3,
#     'base_model_names': ['KNeighbors_BAG_L1',
#      'RandomForest_BAG_L1',
#      'LinearModel_BAG_L1']},
#    'children_info': {'S1F1': {'name': 'S1F1',
#      'model_type': 'GreedyWeightedEnsembleModel',
#      'problem_type': 'multiclass',
#      'eval_metric': 'accuracy',
#      'stopping_metric': 'accuracy',
#      'fit_time': 0.04319596290588379,
#      'num_classes': 6,
#      'quantile_levels': None,
#      'predict_time': None,
#      'val_score': None,
#      'hyperparameters': {'ensemble_size': 25, 'subsample_size': 1000000},
#      'hyperparameters_user': {},
#      'hyperparameters_fit': {'ensemble_size': 15},
#      'hyperparameters_nondefault': [],
#      'ag_args_fit': {'max_memory_usage_ratio': 1.0,
#       'max_time_limit_ratio': 1.0,
#       'max_time_limit': None,
#       'min_time_limit': 0,
#       'valid_raw_types': None,
#       'valid_special_types': None,
#       'ignored_type_group_special': None,
#       'ignored_type_group_raw': None,
#       'get_features_kwargs': None,
#       'get_features_kwargs_extra': None,
#       'predict_1_batch_size': None,
#       'temperature_scalar': None,
#       'drop_unique': False},
#      'num_features': 18,
#      'features': ['KNeighbors_BAG_L1_0',
#       'KNeighbors_BAG_L1_1',
#       'KNeighbors_BAG_L1_2',
#       'KNeighbors_BAG_L1_3',
#       'KNeighbors_BAG_L1_4',
#       'KNeighbors_BAG_L1_5',
#       'RandomForest_BAG_L1_0',
#       'RandomForest_BAG_L1_1',
#       'RandomForest_BAG_L1_2',
#       'RandomForest_BAG_L1_3',
#       'RandomForest_BAG_L1_4',
#       'RandomForest_BAG_L1_5',
#       'LinearModel_BAG_L1_0',
#       'LinearModel_BAG_L1_1',
#       'LinearModel_BAG_L1_2',
#       'LinearModel_BAG_L1_3',
#       'LinearModel_BAG_L1_4',
#       'LinearModel_BAG_L1_5'],
#      'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata at 0x1284b5f10>,
#      'memory_size': 10221,
#      'compile_time': None,
#      'is_initialized': True,
#      'is_fit': True,
#      'is_valid': True,
#      'can_infer': True,
#      'has_learning_curves': False,
#      'num_samples': 6492,
#      'val_in_fit': False,
#      'unlabeled_in_fit': False,
#      'num_cpus': 10,
#      'num_gpus': 0,
#      'model_weights': {'KNeighbors_BAG_L1': np.float64(0.06666666666666667),
#       'RandomForest_BAG_L1': np.float64(0.7333333333333333),
#       'LinearModel_BAG_L1': np.float64(0.2)}}}}},
#  'model_info_failures': {}}
